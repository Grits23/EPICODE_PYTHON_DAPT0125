# %%
# Abbiamo 25 studenti; memorizzare questo dato in una variabile. Utilizzeremo l'operatore di assegnazione =
students = 25

# %%
# Abbiamo 25 studenti; memorizzare questo dato in una variabile e stamparla a video. Utilizzeremo: • l'operatore di assegnazione = • la funzione print()
print(students)
# Out:
# 25

# %%
# Arrivano altri 3 studenti; memorizzare questo dato in un'altra variabile.
more_students = students + 3

# %%
# Creare un'altra variabile ancora che conterrà la somma delle prime due, poi stamparla a video. Utilizzeremo: • la funzione print() per stampare a video
sum_students = students + more_students
print(sum_students)
# Out:
# 53

# %%
# Creare una variabile che contiene la stringa "Epicode", quindi stamparla a video.
epicode_string = "Epicode"
print(epicode_string)
# Out:
# Epicode

# %%
# Abbiamo la variabile: x = 10 Incrementarla di 2 e poi moltiplicarla per 3
x = 10
x = x + 2
x = x * 3
print(x)
# Out:
# 36

# %%
# Creiamo le seguenti stringhe, e per ognuna di esse verifichiamone la lunghezza con la funzione len():
# • str1 = "Windows" • str2 = "Excel" • str3 = "Powerpoint" • str4 = "Word"
str1 = "Windows"
str2 = "Excel"
str3 = "Powerpoint"
str4 = "Word"
len(str1), len(str2), len(str3), len(str4)
# Out:
# (7, 5, 10, 4)

# %%
# Esercizio Calcolare e stampare a video quanti secondi ci sono in un anno non bisestile.
second = 1
minute = second * 60
hour = minute * 60
day = hour * 24
year = day * 365
second_per_year = year/second
print (second_per_year)
# Out:
# 31536000.0

# %%
# Esercizio Abbiamo la seguente stringa: my_string = "I am studying Python"
#• Trasformarla in modo che tutti i caratteri siano maiuscoli (uppercase) • Trasformarla in modo che tutti i caratteri siano minuscoli (lowercase)
#• Sostituire la sottostringa "Python" con la stringa "a lot" • Usare il metodo .strip(); cambia qualcosa? Perché?
#• Usare il metodo .split() per trovare tutte le parole (token)
# Esercizio Abbiamo la seguente stringa: my_string = "I am studying Python"
#• Trasformarla in modo che tutti i caratteri siano maiuscoli (uppercase) • Trasformarla in modo che tutti i caratteri siano minuscoli (lowercase)
#• Sostituire la sottostringa "Python" con la stringa "a lot" • Usare il metodo .strip(); cambia qualcosa? Perché?
#• Usare il metodo .split() per trovare tutte le parole (token)

my_string = "I am studying Python"
print(my_string.upper())
print(my_string.lower())
new_string = my_string.replace("Python", "a lot")
print(new_string)

print(my_string.strip()) #Non cambia nulla perché non ci sono spazi bianchi all'inizio o alla fine della stringa
print(my_string.split())
# Out:
# I AM STUDYING PYTHON
# i am studying python
# I am studying a lot
# I am studying Python
# ['I', 'am', 'studying', 'Python']

# %%
#Esercizio (1/2) Abbiamo due liste, una di studenti e una di corsi:
studenti = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]
corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"]
#Tenendo conto che i dati sono in corrispondenza posizionale, leggiamo con attenzione le due liste.
#Sapendo che Emma segue Data Analyst Faith segue Backend Grace segue Frontend Henry segue Cybersecurity
#alla lista cui mancano dei dati, aggiungiamo i dati mancanti uno alla volta con il metodo .append()
corsi.append("Frontend")
corsi.append("Cybersecurity")
print(studenti)
# Out:
# ['Alex', 'Bob', 'Cindy', 'Dan', 'Emma', 'Faith', 'Grace', 'Henry']
